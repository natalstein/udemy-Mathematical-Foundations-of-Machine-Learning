# %% [markdown]
# <a href="https://colab.research.google.com/github/natalstein/udemy-Mathematical-Foundations-of-Machine-Learning/blob/main/definite_integral_excersize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.integrate import quad

# %%
def g(x):
    return 2*x

# %%
quad(g, 3, 4)
# Out:
# (7.0, 7.771561172376096e-14)
